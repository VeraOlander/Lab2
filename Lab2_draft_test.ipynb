# %%
from numbers import Number
from validate_coordinates import validate_coordinates
from validate_parameters import validate_parameters


# class Shape to represent the center position of the object
from shape import Shape
from circle import Circle


shape1 = Shape(1,0)
shape1
# Out:
# Coordinates: x = 1, y = 0

# %%
shape2 = Shape(5,-4.7)
shape2
# Out:
# Coordinates: x = 5, y = -4.7

# %%
circle1 = Circle(10,-2,9)
circle1
# Out:
# Circle with a radius = 10 and coordinates: x = -2, y = 9

# %%
circle1.area
# Out:
# 314.1592653589793

# %%
circle1.circumference
# Out:
# 62.83185307179586

# %%
str(circle1)
# Out:
# 'This is a circle with a radius = 10 and coordinates: x = -2, y = 9'

# %%
circle2 = Circle(1,3,10)
circle3 = Circle(1,3,5)

# %%
print(circle1==circle2)
# Out:
# False

# %%
print(circle2==circle3)
# Out:
# True

# %%
print(circle3 < circle2)
# Out:
# False

# %%
circle4 = Circle(radius=8)
circle4
# Out:
# Circle with a radius = 8 and coordinates: x = 0, y = 0

# %%
circle4.translate(6,7)
circle4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[277], line 1
# ----> 1 circle4.translate(6,7)
#       2 circle4
#
# File c:\Users\Dell\Documents\GitHub\Lab2\circle.py:51, in Circle.translate(self, move_x, move_y)
#      50 def translate(self, move_x, move_y):
# ---> 51     validate_coordinates(move_x)
#      52     validate_coordinates(move_y)
#      53     self.x +=move_x
#
# NameError: name 'validate_coordinates' is not defined

# %%
circle1.translate(5, 3)
circle1
# Out:
# Circle with a radius = 10 and coordinates: x = 3, y = 12

# %%
circle1.translate("THREE", 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 circle1.translate("THREE", 5)
#
# Cell In[204], line 50, in Circle.translate(self, move_x, move_y)
#      49 def translate(self, move_x, move_y):
# ---> 50     validate_coordinates(move_x)
#      51     validate_coordinates(move_y)
#      52     self.x +=move_x
#
# File c:\Users\Dell\Documents\GitHub\Lab2\validate_coordinates.py:7, in validate_coordinates(coordinate)
#       5 def validate_coordinates(coordinate):
#       6     if not isinstance(coordinate, Number):
# ----> 7             raise TypeError("coordinate must be a number")
#       9     if isinstance(coordinate, bool):
#      10         raise TypeError("coordinate can not be boolean")
#
# TypeError: coordinate must be a number

# %%
circle1.translate(3, False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 circle1.translate(3, False)
#
# Cell In[204], line 51, in Circle.translate(self, move_x, move_y)
#      49 def translate(self, move_x, move_y):
#      50     validate_coordinates(move_x)
# ---> 51     validate_coordinates(move_y)
#      52     self.x +=move_x
#      53     self.y +=move_y
#
# File c:\Users\Dell\Documents\GitHub\Lab2\validate_coordinates.py:10, in validate_coordinates(coordinate)
#       7         raise TypeError("coordinate must be a number")
#       9 if isinstance(coordinate, bool):
# ---> 10     raise TypeError("coordinate can not be boolean")
#
# TypeError: coordinate can not be boolean

# %%
circle4.is_unit_circle()
# Out:
# This is not a unit circle

# %%
circle5=Circle(1)
circle5
# Out:
# Circle with a radius = 1 and coordinates: x = 0, y = 0

# %%
circle5.is_unit_circle()
# Out:
# This is a unit circle

# %%
circle3.is_unit_circle()
# Out:
# This is not a unit circle
