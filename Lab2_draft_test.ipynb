# %%
from numbers import Number
from validate_coordinates import validate_coordinates
from validate_parameters import validate_parameters


# class Shape to represent the center position of the object
from shape import Shape
from circle import Circle
from rectangle import Rectangle

# %%
circle1 = Circle(x=0, y=0, radius=1) 
circle1
# Out:
# Circle with a radius = 1 and coordinates: x = 0, y = 0

# %%
circle2 = Circle(x=1, y=1, radius=1)
circle2
# Out:
# Circle with a radius = 1 and coordinates: x = 1, y = 1

# %%
rectangle2 = Rectangle(2,3)
print(rectangle2)
# Out:
# This is a rectangle with a length = 2, width = 3 and coordinates: x = 0, y = 0

# %%
rectangle1 = Rectangle(x=0, y=0, width=1, length=1)
rectangle1
# Out:
# Rectangle with a length = 1, width = 1 and coordinates: x = 0, y = 0

# %%
print(circle1 == circle2)
# Out:
# True

# %%
print(circle2 == rectangle1)
# Out:
# False

# %%
circle1.translate(5, 3)
circle1
# Out:
# Circle with a radius = 1 and coordinates: x = 5, y = 3

# %%
circle1.translate("THREE", 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 circle1.translate("THREE", 5)
#
# File c:\Users\Dell\Documents\GitHub\Lab2\circle.py:52, in Circle.translate(self, move_x, move_y)
#      51 def translate(self, move_x, move_y):
# ---> 52     validate_coordinates(move_x)
#      53     validate_coordinates(move_y)
#      54     self.x +=move_x
#
# File c:\Users\Dell\Documents\GitHub\Lab2\validate_coordinates.py:7, in validate_coordinates(coordinate)
#       5 def validate_coordinates(coordinate):
#       6     if not isinstance(coordinate, Number):
# ----> 7             raise TypeError("coordinate must be a number")
#       9     if isinstance(coordinate, bool):
#      10         raise TypeError("coordinate can not be boolean")
#
# TypeError: coordinate must be a number

# %%
circle3 = Circle(radius=3)
circle3
# Out:
# Circle with a radius = 3 and coordinates: x = 0, y = 0

# %%
circle3 >= circle1
# Out:
# True

# %%
rectangle2 = Rectangle(width=3, length="5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 rectangle2 = Rectangle(width=3, length="5")
#
# File c:\Users\Dell\Documents\GitHub\Lab2\rectangle.py:8, in Rectangle.__init__(self, length, width, x, y)
#       6 def __init__(self, length, width, x=0, y=0):
#       7     super().__init__(x, y)
# ----> 8     self.length=length
#       9     self.width=width
#
# File c:\Users\Dell\Documents\GitHub\Lab2\rectangle.py:17, in Rectangle.length(self, length)
#      15 @length.setter
#      16 def length(self, length):
# ---> 17     validate_parameters(length)
#      18     self._length = length
#
# File c:\Users\Dell\Documents\GitHub\Lab2\validate_parameters.py:5, in validate_parameters(parameter)
#       3 def validate_parameters(parameter):
#       4     if not isinstance(parameter, Number):
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
fig, ax = plt.subplots()
ax.set(xlim=(-10,10), ylim=(-5,5), xlabel="x", ylabel="y")
circle1.draw_circle(ax)
# Out:
# <Axes: xlabel='x', ylabel='y'>
